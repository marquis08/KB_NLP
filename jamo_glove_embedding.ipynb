# %% [markdown]
# ref: https://www.kaggle.com/hamishdickson/bidirectional-lstm-in-keras-with-glove-embeddings
#
# ref: https://lovit.github.io/nlp/representation/2018/09/05/glove/

# %%
import pandas as pd
import time
import os, gc
import numpy as np
from tqdm import tqdm
import random
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import *
from keras.utils.np_utils import to_categorical
from keras.initializers import Constant
import re

import matplotlib.pyplot as plt
# %matplotlib inline

import torch

# %%
def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(42)

# %%
# %%time
#train_df=pd.read_csv("../KB_NLP/morphs/komo_morphs_train.csv")
#test_df=pd.read_csv("../KB_NLP/morphs/komo_morphs_test.csv")
train_df=pd.read_csv("../KB_NLP/raw_data/train.csv")
test_df=pd.read_csv("../KB_NLP/raw_data/public_test.csv")
# Out:
# CPU times: user 923 ms, sys: 44 ms, total: 967 ms
# Wall time: 967 ms

# %%
pd.set_option('display.max_colwidth',-1)
train_df.head()
# Out:
#    id year_month  \
# 0  0   2017-01
# 1  1   2017-01
# 2  2   2017-01
# 3  4   2017-01
# 4  5   2017-01
#
#                                                                                                                                                                              text  \
# 0  XXX은행성산XXX팀장입니다.행복한주말되세요
# 1  오늘도많이웃으시는하루시작하세요XXX은행 진월동VIP라운지 XXX올림
# 2  안녕하십니까 고객님. XXX은행입니다.금일 납부하셔야 할 금액은 153600원 입니다.감사합니다. 새해 복 많이 받으십시오.XXX은행옥포XXX올림
# 3  XXX 고객님안녕하세요XXX은행 XXX지점입니다지난 한 해 동안 저희 XXX지점에 보내주신 성원에 감사드립니다. 설렘으로 시작한 2017년소망하시는 일 모두 이XXX 고객님의 가정에 늘 건강과 행복이 함께하길 기원하겠습니다. 사랑하는 가족과 함께 정을 나누는 행복한 설 명절 보내세요 XXX은행 XXX지점직원일동
# 4  1월은 새로움이 가득XXX입니다.올 한해 더 많이행복한 한해되시길바랍니다
#
#    smishing
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
from soynlp.hangle import decompose

doublespace_pattern = re.compile('\s+')

def jamo_sentence(sent):

    def transform(char):
        if char == ' ':
            return char
        cjj = decompose(char)
        try:
            len(cjj)
        except:
            return ' '
        if len(cjj) == 1:
            return cjj
        cjj_ = ''.join(c if c != ' ' else '' for c in cjj)
        return cjj_

    sent_ = ''.join(transform(char) for char in sent)
    sent_ = doublespace_pattern.sub(' ', sent_)
    return sent_
# 'ㅇㅓ-ㅇㅣ-ㄱㅗ- ㅋㅔㄱㅋㅔㄱ ㅇㅏ-ㅇㅣ-ㄱㅗ-ㅇㅗ-'

jamo_sentence(train_df.loc[0, 'text'])
# Out:
# ' ㅇㅡㄴㅎㅐㅇㅅㅓㅇㅅㅏㄴ ㅌㅣㅁㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ ㅎㅐㅇㅂㅗㄱㅎㅏㄴㅈㅜㅁㅏㄹㄷㅚㅅㅔㅇㅛ'

# %%
# %%time
test_df['jamo'] = test_df['text'].apply(lambda x: jamo_sentence(x))
train_df['jamo'] = train_df['text'].apply(lambda x: jamo_sentence(x))
# Out:
# CPU times: user 1min 1s, sys: 144 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
train_df.to_csv("../KB_NLP/jamo_data/jamo_train.csv", index=False)
test_df.to_csv("../KB_NLP/jamo_data/jamo_test.csv", index=False)
# Out:
# CPU times: user 3.08 s, sys: 240 ms, total: 3.32 s
# Wall time: 5.91 s

# %%
train_df['jamo'][0]
# Out:
# ' ㅇㅡㄴㅎㅐㅇㅅㅓㅇㅅㅏㄴ ㅌㅣㅁㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ ㅎㅐㅇㅂㅗㄱㅎㅏㄴㅈㅜㅁㅏㄹㄷㅚㅅㅔㅇㅛ'

# %%
raw_corpus_fname = '\n'.join(pd.concat([train_df['jamo'], test_df['jamo']]))
file=open('../KB_NLP/jamo_text.txt','w')
file.write(raw_corpus_fname)
file.close()

# %%
jamo_jumo = pd.concat([train_df['jamo'], test_df['jamo']])

# %%
input_sentences = list(jamo_jumo)

# %%
# Make Co-occurence Matrix by using soynlp
from soynlp.utils import DoublespaceLineCorpus
from soynlp.vectorizer import sent_to_word_contexts_matrix

#corpus_path = '2016-10-20_article_all_normed_ltokenize.txt'
#corpus = DoublespaceLineCorpus(corpus_path, iter_sent=True)

x, idx2vocab = sent_to_word_contexts_matrix(
    input_sentences,
    windows=1,
    min_tf=10,
    tokenizer=lambda x:x.split(), # (default) lambda x:x.split(),
    dynamic_weight=True,
    verbose=True)

print(x.shape) # (36002, 36002)
# Out:
# Create (word, contexts) matrix
#   - counting word frequency from 297570 sents, mem=1.833 Gb
#   - scanning (word, context) pairs from 297570 sents, mem=1.635 Gb
#   - (word, context) matrix was constructed. shape = (38890, 38890)
#   - done
# (38890, 38890)

# %% [markdown]
# ---
# # make every 10 th embeddings with 200dim

# %%
from glove import Corpus, Glove

# %%
glove = Glove(no_components=200, learning_rate=0.01, random_state=42,)
glove.fit(x.tocoo(), epochs=2, no_threads=4, verbose=False)
dictionary = {vocab:idx for idx, vocab in enumerate(idx2vocab)}
glove.add_dictionary(dictionary)

# %%
glove.dictionary
# Out:
# {'ㅇㅗㄹㄹㅣㅁ': 0,
#  'ㅇㅡㄴㅎㅐㅇ': 1,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁ': 2,
#  'ㄱㅏㅁㅅㅏㅎㅏㅂㄴㅣㄷㅏ': 3,
#  'ㅇㅝㄹ': 4,
#  'ㅂㅏㄹㅏㅂㄴㅣㄷㅏ': 5,
#  'ㅅㅜ': 6,
#  'ㅎㅐㅇㅂㅗㄱㅎㅏㄴ': 7,
#  'ㅇㅣㅆㅅㅡㅂㄴㅣㄷㅏ': 8,
#  'ㄱㅘㅇㄱㅗ': 9,
#  'ㅈㅓㅎㅢ': 10,
#  'ㅁㅣㅊ': 11,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅇㅢ': 12,
#  'ㅎㅏㅇㅅㅏㅇ': 13,
#  'ㅂㅗㄴㅐㅅㅔㅇㅛ': 14,
#  'ㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 15,
#  'ㅎㅏㄹㅜ': 16,
#  'ㄲㅗㄱ': 17,
#  'ㅊㅚㄷㅐ': 18,
#  'ㅇㅣㅂㄴㅣㄷㅏ': 19,
#  'ㄴㅕㄴ': 20,
#  'ㄱㅏㅁㅅㅏㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 21,
#  'ㅈㅜㅅㅕㅅㅓ': 22,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 23,
#  'ㅈㅜㅁㅏㄹ': 24,
#  'ㅇㅣㄹ': 25,
#  'ㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 26,
#  'ㄸㅏㄹㅏ': 27,
#  'ㅇㅣㅆㄴㅡㄴ': 28,
#  'ㅈㅣㅈㅓㅁ': 29,
#  'ㅈㅜㅅㅣㅁㅕㄴ': 30,
#  'ㅈㅡㄹㄱㅓㅇㅜㄴ': 31,
#  'ㄱㅏㄴㅡㅇ': 32,
#  'ㅁㅜㄹㅛㅅㅜㅅㅣㄴㄱㅓㅂㅜ': 33,
#  'ㅎㅏㄴㄷㅗ': 34,
#  'ㄷㅚㅅㅔㅇㅛ': 35,
#  'ㅌㅣㅁㅈㅏㅇ': 36,
#  'ㄱㅕㅇㅇㅜ': 37,
#  'ㄲㅏㅈㅣ': 38,
#  'ㅈㅗㅎㅇㅡㄴ': 39,
#  'ㄷㅓ': 40,
#  'ㅁㅏㄴㅇㅝㄴ': 41,
#  'ㅇㅕㄴ': 42,
#  'ㅇㅗㄴㅡㄹㄷㅗ': 43,
#  'ㅎㅏㄴ': 44,
#  'ㄸㅗㄴㅡㄴ': 45,
#  'ㅈㅓㅁ': 46,
#  'ㅎㅏㅂㄴㅣㄷㅏ': 47,
#  'ㅅㅏㅇㄷㅏㅁ': 48,
#  'ㅅㅏㅇㅍㅜㅁ': 49,
#  'ㅂㅜㄴ': 50,
#  'ㄷㅡㅇ': 51,
#  'ㅅㅗㅈㅜㅇㅎㅏㄴ': 52,
#  'ㄱㅡㅁㄹㅣ': 53,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㄲㅔ': 54,
#  'ㅁㅏㄶㅇㅣ': 55,
#  'ㅁㅐㅇㅜ': 56,
#  'ㅊㅚㅅㅓㄴㅇㅡㄹ': 57,
#  'ㅇㅗㄴㅡㄹ': 58,
#  'ㄱㅏㄷㅡㄱㅎㅏㄴ': 59,
#  'ㄷㅏㅂㅈㅏㅇㅇㅡㄹ': 60,
#  'ㅡ': 61,
#  'ㄷㅡㄹㅣㅁ': 62,
#  'ㅅㅣ': 63,
#  'ㅊㅚㅈㅓ': 64,
#  'ㅁㅏㄴ': 65,
#  'ㄷㅐㅎㅏㄴ': 66,
#  'ㅂㅏㄹㅗ': 67,
#  'ㄱㅓㄹㅐㅎㅐ': 68,
#  'ㅇㅏㄴㄴㅐ': 69,
#  'ㄷㅐㅊㅜㄹ': 70,
#  'ㅇㅓㄱ': 71,
#  'ㅈㅔ': 72,
#  'ㄷㅚㅅㅣㄱㅣㄹ': 73,
#  'ㅈㅣㅈㅓㅁㅇㅡㄹ': 74,
#  'ㄷㅐ': 75,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㄲㅔㅅㅓ': 76,
#  'ㅅㅣㄱㅏㄴ': 77,
#  'ㅈㅣㄴㅅㅣㅁㅇㅡㄹㅗ': 78,
#  'ㅈㅓㄴㅎㅘㄹㅡㄹ': 79,
#  'ㄱㅏㄴㅡㅇㅎㅏㅂㄴㅣㄷㅏ': 80,
#  'ㄴㅡㄹ': 81,
#  'ㅎㅏㅁㄲㅔ': 82,
#  'ㄱㅗㄱㅐㄱㅁㅏㄴㅈㅗㄱㄷㅗ': 83,
#  'ㄱㅏㅁㅅㅏㄷㅡㄹㅣㅁㅕ': 84,
#  'ㅇㅡㄴㅎㅐㅇㅇㅡㄹ': 85,
#  'ㅊㅏㄷㅡㅇㅈㅓㄱㅇㅛㅇ': 86,
#  'ㅅㅣㄴㅊㅓㅇㅂㅏㅇㅂㅓㅂ': 87,
#  'ㄱㅓㄹㅐ': 88,
#  'ㄱㅣㅇㅝㄴㅎㅏㅂㄴㅣㄷㅏ': 89,
#  'ㅇㅣㅆㅇㅡㅅㅣㅁㅕㄴ': 90,
#  'ㅌㅗㅇㅎㅐ': 91,
#  'ㅇㅓㄴㅈㅔㄷㅡㄴㅈㅣ': 92,
#  'ㅈㅏㄹ': 93,
#  'ㅇㅢ': 94,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 95,
#  'ㅇㅠㅎㅛㄱㅣㄱㅏㄴ': 96,
#  'ㄷㅗㅇㅜㅁㅇㅣ': 97,
#  'ㄷㅏㅇㅑㅇㅎㅏㄴ': 98,
#  'ㅈㅓㄴㅎㅘ': 99,
#  'ㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 100,
#  'ㅈㅣㄱㅈㅏㅇㅇㅣㄴ': 101,
#  'ㅎㅜ': 102,
#  'ㅈㅏㄱㅕㄱ': 103,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅇㅏㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 104,
#  'ㄹㅗ': 105,
#  'ㅅㅣㄴㅇㅛㅇㄷㅡㅇㄱㅡㅂ': 106,
#  'ㅊㅚㄱㅗ': 107,
#  'ㅁㅏㅁㅜㄹㅣ': 108,
#  'ㅎㅗ': 109,
#  'ㅁㅏㄶㅇㅡㄴ': 110,
#  'ㅁㅗㄷㅜ': 111,
#  'ㄱㅓㄹㅐㅎㅐㅈㅜㅅㅕㅅㅓ': 112,
#  'ㅁㅏㄴㅇㅝㄴㄲㅏㅈㅣ': 113,
#  'ㅅㅣㅁㅇㅢㅍㅣㄹ': 114,
#  'ㄷㅐㄹㅣ': 115,
#  'ㄷㅓㅇㅜㄱ': 116,
#  'ㅇㅣㅇㅛㅇㅎㅐㅈㅜㅅㅕㅅㅓ': 117,
#  'ㅂㅏㄹㅏㅁㅕ': 118,
#  'ㄱㅐㅇㅝㄹ': 119,
#  'ㅂㅗㄴ': 120,
#  'ㄱㅖㅈㅏㅇ': 121,
#  'ㄷㅚㅂㄴㅣㄷㅏ': 122,
#  'ㅇㅓㅄㅇㅣ': 123,
#  'ㅇㅔㅅㅓ': 124,
#  'ㄷㅐㅎㅐ': 125,
#  'ㅈㅡㄹㄱㅓㅂㄱㅗ': 126,
#  'ㅁㅗㄷㅡㄴ': 127,
#  'ㅇㅕㄴㄹㅏㄱ': 128,
#  'ㅎㅕㄴㅈㅐ': 129,
#  'ㄱㅘㄴㄹㅕㄴ': 130,
#  'ㄷㅏㅎㅏㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 131,
#  'ㅁㅐㅇㅜㄷㅗㅇㅇㅢ': 132,
#  'ㄴㅗㅍㅇㅡㄴ': 133,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅇㅡㄹ': 134,
#  'ㄱㅓㄴㄱㅏㅇ': 135,
#  'ㅇㅝㄹㅇㅢ': 136,
#  'ㄸㅐ': 137,
#  'ㅋㅡㄴ': 138,
#  'ㅇㅣㅅㅏㅇ': 139,
#  'ㄴㅐ': 140,
#  'ㄱㅖㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ': 141,
#  'ㅈㅓㄴㄷㅏㅁㅈㅣㄱㅇㅝㄴ': 142,
#  'ㅇㅡㄹㅗ': 143,
#  'ㅇㅣㅇㅛㅇㅎㅐ': 144,
#  'ㅅㅔㅇㅐㄱㄱㅗㅇㅈㅔ': 145,
#  'ㅅㅐㄹㅗㅇㅜㄴ': 146,
#  'ㅎㅏㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 147,
#  'ㅁㅜㄴㅈㅏㄹㅗ': 148,
#  'ㅎㅐㅇㅂㅗㄱㅇㅣ': 149,
#  'ㅇㅣ': 150,
#  'ㅍㅕㄴㅇㅏㄴㅎㅏㄴ': 151,
#  'ㄱㅏㅁㅅㅏ': 152,
#  'ㅊㅚ': 153,
#  'ㅊㅣㄴㅈㅓㄹㅎㅣ': 154,
#  'ㅇㅟㅎㅏㄴ': 155,
#  'ㅇㅣㅈㅏㅁㅏㄴ': 156,
#  'ㅇㅣㄹㅏㄱㅗ': 157,
#  'ㄱㅜㅇㄱㅡㅁㅎㅏㅅㅣㄴ': 158,
#  'ㄷㅏㅅㅣ': 159,
#  'ㅊㅏㅈㅇㅏㅈㅜㅅㅕㅅㅓ': 160,
#  'ㅇㅏㄴㄴㅐㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 161,
#  'ㅊㅏㅈㅏㅇ': 162,
#  'ㅇㅓㅂㅁㅜㅊㅓㄹㅣ': 163,
#  'ㄹㅣㅂㅡ': 164,
#  'ㅇㅣㅆㄷㅗㄹㅗㄱ': 165,
#  'ㅇㅟㅎㅐ': 166,
#  'ㅈㅜㄴㅂㅓㅂㄱㅏㅁㅅㅣㅇㅣㄴ': 167,
#  'ㅇㅣㄴㅎㅐ': 168,
#  'ㄸㅏㄸㅡㅅㅎㅏㄴ': 169,
#  'ㅁㅏㄴㄱㅣ': 170,
#  'ㅅㅔ': 171,
#  'ㅎㅏㄹㅜㄷㅚㅅㅔㅇㅛ': 172,
#  'ㅎㅖㅌㅐㄱ': 173,
#  'ㅇㅏㅍㅇㅡㄹㅗㄷㅗ': 174,
#  'ㅊㅜㄱㅏ': 175,
#  'ㅈㅏㄱㅇㅡㄴㅏ': 176,
#  'ㄷㅡㅇㄱㅡㅂ': 177,
#  'ㄱㅏㄷㅡㄱ': 178,
#  'ㅇㅡㄴㅎㅐㅇㅇㅣ': 179,
#  'ㅅㅏㅇㄷㅏㅁㅇㅡㄹㅗ': 180,
#  'ㄱㅡ': 181,
#  'ㅇㅣㅆㄷㅏㅁㅕㄴ': 182,
#  'ㅅㅜㅅㅣㄴㅇㅡㄹ': 183,
#  'ㅎㅏㄴㅡㄴ': 184,
#  'ㅇㅡㄴㅎㅐㅇㅇㅔㅅㅓ': 185,
#  'ㅇㅣㅂㅓㄴ': 186,
#  'ㅊㅚㄱㅡㄴ': 187,
#  'ㅎㅗㄱㅅㅣ': 188,
#  'ㅇㅕㄴㅂㅗㅇㄷㅐㅂㅣ': 189,
#  'ㄱㅣㅈㅗㄴ': 190,
#  'ㅈㅓㄴㅎㅘㄴㄱㅏㄴㅡㅇ': 191,
#  'ㅇㅏㄶㄷㅗㄹㅗㄱ': 192,
#  'ㅈㅏㅊㅔ': 193,
#  'ㅈㅜㅇ': 194,
#  'ㅁㅏㅅㅣㄱㅗ': 195,
#  'ㅅㅏㅇㄷㅏㅁㅎㅐ': 196,
#  'ㅇㅝㄴㄹㅣㄱㅡㅁ': 197,
#  'ㅇㅣㄹㅇㅣ': 198,
#  'ㅂㅏㅇㅅㅣㄱㅇㅡㄹㅗ': 199,
#  'ㅎㅏㅅㅣㄴㅡㄴ': 200,
#  'ㅇㅡㄹ': 201,
#  'ㅈㅏㅇㅠㄹㅗㅂㄱㅔ': 202,
#  'ㅈㅜ': 203,
#  'ㅂㅏㄷㅇㅡㅅㅣㅁㅕㄴ': 204,
#  'ㅇㅔ': 205,
#  'ㅎㅐ': 206,
#  'ㄹㅡㄹ': 207,
#  'ㄱㅡㅁㄹㅣㄹㅡㄹ': 208,
#  'ㅊㅓㄴㅁㅏㄴㅇㅝㄴ': 209,
#  'ㅇㅝㄴㅎㅏㅅㅣㄴㅡㄴ': 210,
#  'ㄷㅡㅇㄱㅡㅂㅇㅔ': 211,
#  'ㅇㅡㄴ': 212,
#  'ㄱㅣㅂㅜㄴ': 213,
#  'ㅇㅓㄴㅈㅔㄴㅏ': 214,
#  'ㅅㅏㅇㄷㅏㅁㅇㅣ': 215,
#  'ㅇㅕㄴㄱㅡㅁ': 216,
#  'ㄷㅗㅇㅘㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 217,
#  'ㅈㅜㅅㅣㄱㅓㄴㅏ': 218,
#  'ㅈㅓㅁㅇㅡㄴ': 219,
#  'ㄴㅗㄹㅕㄱㅎㅏㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 220,
#  'ㅍㅗㅇㅣㄴㅌㅡ': 221,
#  'ㅇㅏㄴㅈㅓㄴㅎㅏㄴ': 222,
#  'ㅈㅣㄴㅎㅐㅇㄱㅏㄴㅡㅇ': 223,
#  'ㅈㅏㅈㅇㅡㄴ': 224,
#  'ㅎㅏㄹㅜㄷㅗ': 225,
#  'ㅎㅏㄹ': 226,
#  'ㄱㅏㄷㅡㄱㅎㅏㅅㅣㄱㅣㄹ': 227,
#  'ㅈㅓㄱㅇㅛㅇ': 228,
#  'ㅅㅣㅈㅜㅇㅇㅡㄴㅎㅐㅇㅂㅗㄷㅏ': 229,
#  'ㄱㅓㄴㅅㅜㄱㅏ': 230,
#  'ㅅㅏㅇㄱㅘㄴㅇㅓㅄㅇㅣ': 231,
#  'ㅅㅓㅂㅣㅅㅡㄹㅗ': 232,
#  'ㄷㅐㄹㅣㅇㅣㅂㄴㅣㄷㅏ': 233,
#  'ㅂㅜㅌㅓ': 234,
#  'ㅈㅜㅅㅣㄴㄷㅏㅁㅕㄴ': 235,
#  'ㅂㅓㄴ': 236,
#  'ㅈㅓ': 237,
#  'ㄷㅏㅎㅐ': 238,
#  'ㅂㅗㄴㅐㅅㅣㄱㅣㄹ': 239,
#  'ㄷㅏㅇㅜㄴㄹㅗㄷㅡ': 240,
#  'ㅇㅝㄴ': 241,
#  'ㅅㅐㅎㅐ': 242,
#  'ㅇㅏㄶㅅㅡㅂㄴㅣㄷㅏ': 243,
#  'ㅎㅖㅌㅐㄱㅇㅣ': 244,
#  'ㅊㅜㄱㅏㅈㅣㄴㅎㅐㅇㅇㅣ': 245,
#  'ㅅㅏㅇㄷㅏㅁㅇㅣㄹㅏㄱㅗ': 246,
#  'ㅇㅐㅂ': 247,
#  'ㅁㅏㅇㅡㅁㅇㅡㄹㅗ': 248,
#  'ㄷㅡㄹㅣㄴㅡㄴ': 249,
#  'ㅎㅏㄴㄷㅏㄹ': 250,
#  'ㅁㅜㄹㅛㄹㅗ': 251,
#  'ㅅㅏㅇㅛㅇㅇㅣ': 252,
#  'ㅎㅏㄴㅂㅓㄴㅇㅔ': 253,
#  'ㄱㅓㅂㅜ': 254,
#  'ㄸㅗㅎㅏㄴ': 255,
#  'ㅌㅣㅁㅈㅏㅇㅇㅗㄹㄹㅣㅁ': 256,
#  'ㅅㅜㅅㅜㄹㅛ': 257,
#  'ㄱㅘㄴㄹㅣㄱㅏ': 258,
#  'ㅇㅜㄷㅐ': 259,
#  'ㅇㅣㅈㅏㅁㅏㄴㄴㅐㄴㅡㄴ': 260,
#  'ㅈㅓㄴㅎㅘㅈㅜㅅㅣㅁㅕㄴ': 261,
#  'ㅇㅠㅇㅢㅎㅏㅅㅣㄱㅗ': 262,
#  'ㅁㅜㄴㅈㅏㄹㅡㄹ': 263,
#  'ㅂㅗㄱ': 264,
#  'ㅈㅏㅅㅔㅎㅏㄴ': 265,
#  'ㅌㅣㅁㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ': 266,
#  'ㅈㅓㅇㅂㅜㅈㅣㅇㅝㄴ': 267,
#  'ㄱㅣㅂㅜㄴㅈㅗㅎㅇㅡㄴ': 268,
#  'ㅁㅜㄹㅛㄱㅓㅂㅜ': 269,
#  'ㄴㅐㅈㅓㅁ': 270,
#  'ㅂㅜㅊㅐ': 271,
#  'ㅅㅏㅇㅅㅡㅇ': 272,
#  'ㄴㅏㄹㅆㅣㅇㅔ': 273,
#  'ㅇㅓㄴㅈㅔㄷㅡㄴ': 274,
#  'ㅊㅏㄷㅡㅇ': 275,
#  'ㅅㅣㄴㄱㅠ': 276,
#  'ㄷㅚㅇㅓㅆㅅㅡㅂㄴㅣㄷㅏ': 277,
#  'ㅇㅣㅅㅏㅇㅇㅢ': 278,
#  'ㅊㅓㄴ': 279,
#  'ㅂㅜㅊㅐㄹㅡㄹ': 280,
#  'ㅂㅏㄷㅇㅡㅅㅣㄹ': 281,
#  'ㅎㅘㄹㄱㅣㅊㅏㄴ': 282,
#  'ㅎㅢㅁㅏㅇㅎㅏㅈㅣ': 283,
#  'ㅊㅓㄴㅁㅏㄴㅇㅝㄴㄲㅏㅈㅣ': 284,
#  'ㅇㅏㅍㅇㅡㄹㅗ': 285,
#  'ㅈㅔㄱㅏ': 286,
#  'ㅈㅜㄹㅇㅕ': 287,
#  'ㅋㅏㄷㅡㄹㅗㄴ': 288,
#  'ㅈㅣㄱㅈㅓㅂ': 289,
#  'ㄱㅐㅇㅣㄴㅎㅕㅇㅌㅚㅈㅣㄱㅇㅕㄴㄱㅡㅁ': 290,
#  'ㄱㅏㅈㅓㅇㅇㅔ': 291,
#  'ㄴㅏㅈㅇㅡㄴ': 292,
#  'ㄱㅏ': 293,
#  'ㅇㅓㅄㅅㅡㅂㄴㅣㄷㅏ': 294,
#  'ㅈㅓㄴㅎㅘㄴ': 295,
#  'ㅇㅠㅇㅣㄱㅎㅏㄴ': 296,
#  'ㅁㅐㅇㅝㄹ': 297,
#  'ㅎㅏㄴㄱㅜㄱ': 298,
#  'ㅁㅏㄴㄷㅡㄹㅇㅓ': 299,
#  'ㄱㅗㄱㅐㄱ': 300,
#  'ㅅㅏㅇㅛㅇㅈㅜㅇㅇㅣㄴ': 301,
#  'ㅊㅏㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ': 302,
#  'ㅇㅣㅈㅈㅣ': 303,
#  'ㅇㅣㄹㅓㅎㄱㅔ': 304,
#  'ㅇㅣㅂㄹㅕㄱ': 305,
#  'ㅇㅓㄹㅕㅂㄷㅏㅁㅕㄴ': 306,
#  'ㅌㅗㅇ': 307,
#  'ㄱㅝㄴㅎㅐㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 308,
#  'ㅇㅏㄹㅇㅏㅇㅑ': 309,
#  'ㅇㅣㄴㅅㅏㄹㅡㄹ': 310,
#  'ㅂㅗㄴㅐㅅㅣㄱㅣ': 311,
#  'ㄱㅏㅈㅏㅇ': 312,
#  'ㅅㅏㅇㅎㅘㄴ': 313,
#  'ㅈㅏㄱㅕㄱㅈㅗㄱㅓㄴ': 314,
#  'ㅇㅣㅂㅔㄴㅌㅡ': 315,
#  'ㅈㅓㄴㅡㄴ': 316,
#  'ㅂㅏㅃㅡㅅㅣㄴ': 317,
#  'ㅎㅏㄴㅈㅜ': 318,
#  'ㅅㅣㄴㅇㅛㅇㄷㅐㅊㅜㄹ': 319,
#  'ㄱㅓㅅㅇㅡㄹ': 320,
#  'ㅇㅓㅈㅔ': 321,
#  'ㅇㅕㄹㅓㄱㅓㄴㅇㅡㄹㅗ': 322,
#  'ㄷㅡㅇㄱㅡㅂㅇㅣㄴㅐㅇㅢ': 323,
#  'ㅇㅣㄴㅎㅏㄴ': 324,
#  'ㄴㅐㅇㅛㅇ': 325,
#  'ㅊㅐㅁㅜㅌㅗㅇㅎㅏㅂ': 326,
#  'ㅅㅏㅇㅍㅜㅁㅇㅢ': 327,
#  'ㅂㅜㅊㅐㄱㅏ': 328,
#  'ㄱㅗㄱㅡㅁㄹㅣ': 329,
#  'ㅈㅣㅅㅣㄱㅇㅡㄹ': 330,
#  'ㅅㅏㅇㅍㅜㅁㅇㅡㄹ': 331,
#  'ㄸㅗ': 332,
#  'ㅈㅜㄱㅓㄹㅐ': 333,
#  'ㅎㅐㅇㅂㅗㄱㅎㅏㅅㅔㅇㅛ': 334,
#  'ㅈㅣㄴㅎㅐㅇㅇㅣ': 335,
#  'ㅇㅣㅂㅊㅜㄹㄱㅡㅁ': 336,
#  'ㅅㅣㄴㅇㅛㅇㄷㅡㅇㄱㅡㅂㅇㅣ': 337,
#  'ㄷㅗㅇㅘㄷㅡㄹㅣㄴ': 338,
#  'ㅎㅏㅅㅔㅇㅛ': 339,
#  'ㅇㅗㄴㅡㄹㅇㅡㄴ': 340,
#  'ㅇㅣㄹㅂㅜㅌㅓ': 341,
#  'ㅇㅟ': 342,
#  'ㅈㅓㄹㅡㄹ': 343,
#  'ㅁㅏㄶㅇㅏ': 344,
#  'ㄷㅏㄹㅡㅁㅇㅣ': 345,
#  'ㄷㅐㅅㅏㅇㅇㅡㄹㅗ': 346,
#  'ㅇㅕㄴㅊㅔㅅㅏㅅㅣㄹㅇㅣ': 347,
#  'ㄴㅏㅈㅇㅡㄴㄱㅡㅁㄹㅣㄹㅗ': 348,
#  'ㅂㅏㄷㅇㅡㅅㅔㅇㅛ': 349,
#  'ㄱㅘㄴㄹㅣ': 350,
#  'ㅈㅓㄴㅕㄱ': 351,
#  'ㅇㅓㅄㅇㅓㄷㅗ': 352,
#  'ㅁㅓㄴㅈㅓ': 353,
#  'ㅇㅝㄴㄱㅡㅁㅇㅣㅈㅏ': 354,
#  'ㅅㅓㅂㅣㅅㅡ': 355,
#  'ㅎㅐㅇㅂㅗㄱㅇㅡㄹ': 356,
#  'ㄷㅏㅇㅅㅏ': 357,
#  'ㅇㅕㅇㅎㅑㅇㅇㅡㄹ': 358,
#  'ㄲㅜㅈㅜㄴㅎㅏㄴ': 359,
#  'ㄱㅏㅌㅇㅡㄴ': 360,
#  'ㄱㅏㄴㅡㅇㅎㅏㄴ': 361,
#  'ㄷㅚㄹ': 362,
#  'ㅈㅓㅇㅈㅣㄱㅎㅏㄱㅗ': 363,
#  'ㄲㅜㅈㅜㄴㅎㅣ': 364,
#  'ㅇㅏㄴㅣㄹㅏ': 365,
#  'ㅊㅜㅊㅓㄴ': 366,
#  'ㅇㅣㅎㅜ': 367,
#  'ㄱㅡㅁㅇㅠㅇㄱㅝㄴ': 368,
#  'ㅊㅣㄴㅈㅓㄹㅎㅏㄱㅗ': 369,
#  'ㅅㅏㄹㅏㅇㄱㅘ': 370,
#  'ㅎㅏㄴㄷㅗㄹㅡㄹ': 371,
#  'ㅍㅣㄹㅇㅛㅎㅏㄴ': 372,
#  'ㅂㅏㄹㅅㅗㅇㄷㅚㅈㅣ': 373,
#  'ㄷㅐㅊㅜㄹㄱㅡㅁ': 374,
#  'ㄴㅏㅁㅇㅡㄴ': 375,
#  'ㅈㅜㅅㅣㄱㅣ': 376,
#  'ㅇㅕㄴㅅㅗㄷㅡㄱ': 377,
#  'ㅅㅓㅂㅣㅅㅡㄹㅡㄹ': 378,
#  'ㅁㅏㄶㅇㅏㅅㅓ': 379,
#  'ㅇㅏㄶㅇㅡㅅㅣㄹ': 380,
#  'ㄱㅕㅇㅇㅜㅇㅔㄴㅡㄴ': 381,
#  'ㅂㅜㄴㄷㅡㄹㅇㅡㄴ': 382,
#  'ㅁㅏㄱㅏㅁ': 383,
#  'ㅅㅏㅇㄷㅏㅁㅇㅡㄹ': 384,
#  'ㅇㅓㅂㅁㅜ': 385,
#  'ㄷㅡㅇㄱㅡㅂㄱㅘ': 386,
#  'ㅂㅓㄹㅆㅓ': 387,
#  'ㅇㅝㄹㅇㅣㅂㄴㅣㄷㅏ': 388,
#  'ㄷㅚㅇㅓ': 389,
#  'ㅌㅗㅇㅎㅏㅂ': 390,
#  'ㅇㅏㄴ': 391,
#  'ㅈㅜㅁㅏㄹㄷㅚㅅㅔㅇㅛ': 392,
#  'ㅎㅏㄹㅏㄱ': 393,
#  'ㅁㅏㅈㅣㅁㅏㄱ': 394,
#  'ㅈㅏㅊㅔㄷㅡㅇㄱㅡㅂㅇㅡㄹㅗ': 395,
#  'ㅊㅜㅊㅓㄴㅎㅐ': 396,
#  'ㄱㅗㅁㅣㄴㅎㅏㅈㅣ': 397,
#  'ㄱㅓㄴㄱㅏㅇㄱㅘ': 398,
#  'ㅈㅗㄱㅣ': 399,
#  'ㅍㅕㄴㅎㅏㄱㅔ': 400,
#  'ㅈㅓㅇㅁㅏㄹ': 401,
#  'ㄱㅣㅈㅜㄴ': 402,
#  'ㅌㅡㄱㅈㅣㅇ': 403,
#  'ㄱㅏㅁㅅㅏㅇㅢ': 404,
#  'ㄱㅐ': 405,
#  'ㄷㅐㅊㅜㄹㄱㅏㄴㅡㅇ': 406,
#  'ㅈㅣㄱㅡㅁ': 407,
#  'ㄱㅓㄹㅐㄱㅏ': 408,
#  'ㅇㅘㅈㅜㅇㅇㅔ': 409,
#  'ㄱㅣㅇㅓㅂㄹㅣㅅㅡㅌㅡㅇㅔ': 410,
#  'ㅇㅡㄴㅎㅐㅇㅇㅔ': 411,
#  'ㅅㅣㅋㅕ': 412,
#  'ㅇㅣㅆㅇㅓ': 413,
#  'ㅎㅏㅂ': 414,
#  'ㄱㅓㄴㅇㅡㄹㅗ': 415,
#  'ㅁㅏㄴㄱㅣㅇㅣㄹㅅㅣㄹㅗ': 416,
#  'ㅌㅚㅈㅣㄱㅇㅕㄴㄱㅡㅁ': 417,
#  'ㄷㅐㄷㅏㄴㅎㅣ': 418,
#  'ㅇㅣㄹㅁㅏㄴ': 419,
#  'ㅇㅕㄴㄹㅏㄱㅇㅡㄹ': 420,
#  'ㅁㅣㄷㄱㅗ': 421,
#  'ㅎㅏㅁㄲㅔㅎㅏㄴㅡㄴ': 422,
#  'ㄱㅓㅅ': 423,
#  'ㅎㅐㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 424,
#  'ㅇㅡㄴㅎㅐㅇㄱㅝㄴㅇㅡㄹㅗ': 425,
#  'ㄱㅖㅈㅏㅇㅇㅗㄹㄹㅣㅁ': 426,
#  'ㅇㅣㅆㄱㅔ': 427,
#  'ㅍㅗㅇㅣㄴㅌㅡㄹㅡㄹ': 428,
#  'ㅇㅕㄴㄱㅏㄴ': 429,
#  'ㅈㅜㅇㅛ': 430,
#  'ㅁㅜㄴㅈㅏㅇㅖㅇㅑㄱ': 431,
#  'ㅅㅏㅇㅅㅡㅇㅇㅔ': 432,
#  'ㅇㅣㄴㅅㅏㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 433,
#  'ㅊㅗㅇ': 434,
#  'ㄴㅡㄴ': 435,
#  'ㅈㅡㄹㄱㅓㅂㄱㅔ': 436,
#  'ㅂㅗㅅㅔㅇㅛ': 437,
#  'ㄱㅘㄴㅅㅣㅁㅇㅣ': 438,
#  'ㅇㅏㄹㅡㅁㄷㅏㅇㅜㄴ': 439,
#  'ㄱㅏㄷㅡㄱㅎㅏㅅㅔㅇㅛ': 440,
#  'ㅇㅣㅆㅇㅡㄹ': 441,
#  'ㅇㅏㄴㄴㅐㅊㅏ': 442,
#  'ㅍㅗㅎㅏㅁ': 443,
#  'ㅎㅘㄱㅇㅣㄴ': 444,
#  'ㅁㅜㄷㅏㅁㅂㅗ': 445,
#  'ㅅㅏㅇㅍㅜㅁㅇㅡㄹㅗ': 446,
#  'ㅂㅜㅌㅏㄱ': 447,
#  'ㅁㅏㄶㄷㅏㅁㅕㄴ': 448,
#  'ㅂㅐㄱㅁㅏㄴㅇㅝㄴ': 449,
#  'ㄴㅏㅂㅇㅣㅂㅇㅐㄱ': 450,
#  'ㄷㅐㅊㅜㄹㅇㅡㄹ': 451,
#  'ㅅㅓㄹㅊㅣ': 452,
#  'ㅅㅏㅎㅏㅇㅇㅡㄴ': 453,
#  'ㅊㅜㄹ': 454,
#  'ㅇㅏㄶㄱㅗ': 455,
#  'ㅎㅐㅇㅇㅜㄴㅇㅣ': 456,
#  'ㄱㅐㅇㅝㄹㄱㅏㄴ': 457,
#  'ㄱㅣㅇㅓㅂ': 458,
#  'ㅎㅏㅅㅣㄱㅣㄹ': 459,
#  'ㄱㅘㄴㅅㅣㅁㅇㅡㄹ': 460,
#  'ㅅㅏㄹㅏㅇㅇㅔ': 461,
#  'ㄷㅐㅊㅜㄹㅇㅣ': 462,
#  'ㅇㅣㄺㅇㅓ': 463,
#  'ㅇㅣㅆㅇㅡㄴㅣ': 464,
#  'ㅈㅓㄱㅡㅁㄹㅣㄹㅗ': 465,
#  'ㄱㅏㅁㄱㅣ': 466,
#  'ㅁㅏㄴㅈㅗㄱㄷㅗ': 467,
#  'ㅈㅣㄴㅎㅐㅇ': 468,
#  'ㅍㅗㅇㅣㄴㅌㅡㄹㅗ': 469,
#  'ㅈㅗㅊㅣㄹㅡㄹ': 470,
#  'ㅇㅣㅎㅏ': 471,
#  'ㅇㅣㅈㅏ': 472,
#  'ㅇㅣㅁㅣ': 473,
#  'ㅇㅣㅈㅔㄹㅏㄷㅗ': 474,
#  'ㄱㅓㄴㄱㅏㅇㅎㅏㅅㅣㄱㅗ': 475,
#  'ㅇㅕㄴㄹㅏㄱㅈㅜㅅㅣㅁㅕㄴ': 476,
#  'ㅇㅝㄹㅇㅛㅇㅣㄹ': 477,
#  'ㅅㅣㄴㅊㅓㅇㅈㅏ': 478,
#  'ㅅㅜㅅㅣㄴㄱㅓㅂㅜ': 479,
#  'ㅈㅏㄱㅡㅁㅇㅣ': 480,
#  'ㄴㅏㄹ': 481,
#  'ㅇㅣㅎㅏㅇㅣㄴ': 482,
#  'ㄹㅣㅂㅡㅁㅔㅇㅣㅌㅡ': 483,
#  'ㅃㅏㄹㅡㄱㅔ': 484,
#  'ㅂㅐㄲㅏㅈㅣ': 485,
#  'ㅂㅗㄴㅈㅓㅁ': 486,
#  'ㅁㅏㅇㅡㅁ': 487,
#  'ㅁㅜㄴㅇㅢㅅㅏㅎㅏㅇ': 488,
#  'ㅇㅓㅄㅇㅡㅅㅕㅆㄴㅡㄴㅈㅣㅇㅛ': 489,
#  'ㅈㅏㅅㅏㄴㄱㅘㄴㄹㅣ': 490,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㄱㅘ': 491,
#  'ㅂㅗㄴㅐㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 492,
#  'ㅇㅣㄹㄲㅏㅈㅣ': 493,
#  'ㄱㅡㅁㅇㅠㅇ': 494,
#  'ㄱㅏㅇㅡㄹ': 495,
#  'ㅈㅓㄴㅎㅘㅈㅜㅅㅔㅇㅛ': 496,
#  'ㅈㅜㅁㅏㄹㅂㅗㄴㅐㅅㅔㅇㅛ': 497,
#  'ㄱㅏㄲㅏㅇㅜㄴ': 498,
#  'ㅈㅓㄴㅎㅕ': 499,
#  'ㅎㅏㄴㅂㅓㄴ': 500,
#  'ㄷㅚㅅㅣㄱㅣ': 501,
#  'ㅌㅗㅇㅎㅘ': 502,
#  'ㄴㅐㄴㅡㄴ': 503,
#  'ㅈㅓㄴㅎㅘㄴㅅㅣㄴㅇㅛㅇㄷㅡㅇㄱㅡㅂ': 504,
#  'ㅎㅘㄴㅈㅓㄹㄱㅣ': 505,
#  'ㄷㅡㅇㄱㅡㅂㄲㅏㅈㅣ': 506,
#  'ㅂㅜ': 507,
#  'ㅇㅗㄹㅎㅐ': 508,
#  'ㄱㅡㅁㄹㅣㄹㅗ': 509,
#  'ㄷㅐㅊㅜㄹㄹㅗ': 510,
#  'ㄴㅓㅁㅜ': 511,
#  'ㄴㅕㄴㅇㅣㅅㅏㅇ': 512,
#  'ㄱㅘㅈㅏㅇ': 513,
#  'ㅁㅏㄶㅇㅡㄴㅣ': 514,
#  'ㅇㅗㅎㅜ': 515,
#  'ㅅㅐㄹㅗㅂㄱㅔ': 516,
#  'ㅍㅏㄴㄷㅏㄴㅎㅏㅁㅡㄹㅗ': 517,
#  'ㅎㅗㄱㅇㅡㄴ': 518,
#  'ㄷㅡㄴㄷㅡㄴㅎㅏㄴ': 519,
#  'ㅁㅜㄴㅇㅢ': 520,
#  'ㅎㅐㅇㅂㅗㄱㅎㅏㄱㅔ': 521,
#  'ㅈㅗㅇㅎㅏㅂㄱㅡㅁㅇㅠㅇㅅㅔㄴㅌㅓ': 522,
#  'ㄷㅐㅅㅏㅇ': 523,
#  'ㅋㅏㄷㅡ': 524,
#  'ㅈㅏㅊㅔㄷㅡㅇㄱㅡㅂㄱㅘ': 525,
#  'ㄹㅣㅅㅡㅌㅡㅇㅔ': 526,
#  'ㄴㅐㅇㅓ': 527,
#  'ㅍㅓㅈㅕㅇㅣㅆㄴㅡㄴ': 528,
#  'ㅃㅏㄹㅡㄴ': 529,
#  'ㅈㅗㅅㅏ': 530,
#  'ㄷㅗㅇㅜㅁㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 531,
#  'ㄷㅐㄹㅣㅇㅗㄹㄹㅣㅁ': 532,
#  'ㅅㅡㅌㅏㅇㅏㄹㄹㅣㅁ': 533,
#  'ㄱㅏㅌㅅㅡㅂㄴㅣㄷㅏ': 534,
#  'ㅋㅏㅋㅏㅇㅗㅌㅗㄱ': 535,
#  'ㅅㅏㅇㅍㅜㅁㅌㅡㄱㅈㅣㅇ': 536,
#  'ㄷㅗㅇㅇㅢ': 537,
#  'ㅎㅐㅇㅂㅗㄱㅎㅏㄱㅗ': 538,
#  'ㅁㅓㅅㅈㅣㄴ': 539,
#  'ㅂㅗㄴㅐㅈㅜㅅㅣㄱㅓㄴㅏ': 540,
#  'ㅈㅜㅅㅣㄴㅡㄴ': 541,
#  'ㄴㅜㄱㅜㄴㅏ': 542,
#  'ㄷㅏㄹ': 543,
#  'ㅇㅕㄹㅅㅣㅁㅎㅣ': 544,
#  'ㄱㅏㄴㄷㅏㄴㅎㅏㄱㅔ': 545,
#  'ㄱㅣㄱㅏㄴ': 546,
#  'ㅇㅑㅇㅎㅐ': 547,
#  'ㅇㅏㄴㅣㄹㅏㄷㅗ': 548,
#  'ㅅㅏㅇㅍㅜㅁㅇㅣㅂㄴㅣㄷㅏ': 549,
#  'ㅂㅜㄹㄱㅏㅎㅏㅂㄴㅣㄷㅏ': 550,
#  'ㄹㅏㄴㅡㄴ': 551,
#  'ㄴㅓㅁㅊㅣㄴㅡㄴ': 552,
#  'ㅅㅏㅇㅍㅜㅁㅇㅣ': 553,
#  'ㅁㅣㅊㅣㅈㅣ': 554,
#  'ㅈㅓㅂㅅㅜㅈㅏㄱㅏ': 555,
#  'ㅈㅓㄴㅕㄱㅅㅣㄱㅏㄴ': 556,
#  'ㄱㅘㄴㄹㅣㅎㅏㄱㅣ': 557,
#  'ㅈㅣㅂㅏㅇㅅㅗㄷㅡㄱㅅㅔㅍㅗㅎㅏㅁ': 558,
#  'ㄷㅏㅂㅂㅕㄴㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 559,
#  'ㅃㅏㄹㅡㄴㅅㅣㄴㅊㅓㅇ': 560,
#  'ㅍㅕㄴㄹㅣㅎㅏㄴ': 561,
#  'ㅂㅜㅈㅣㅈㅓㅁㅈㅏㅇ': 562,
#  'ㄱㅏㅇㅣㅂㅎㅏㅅㅣㅁㅕㄴ': 563,
#  'ㄷㅡㅇㄹㅗㄱㅇㅡㄹ': 564,
#  'ㅎㅖㅌㅐㄱㅇㅡㄹ': 565,
#  'ㅈㅗㅎㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 566,
#  'ㅎㅘㄴㅇㅠㄹㅇㅜㄷㅐ': 567,
#  'ㅁㅗㄱㄹㅗㄱㅇㅔ': 568,
#  'ㅇㅝㄴㄹㅣㄱㅡㅁㄱㅠㄴㄷㅡㅇㅂㅏㅇㅅㅣㄱㅇㅡㄹ': 569,
#  'ㅇㅓㅄㄷㅗㄹㅗㄱ': 570,
#  'ㅅㅓㅇㅅㅣㅁㄲㅓㅅ': 571,
#  'ㄷㅚㄴㅡㄴ': 572,
#  'ㅁㅜㄴㅈㅏ': 573,
#  'ㅎㅘㄹㅉㅏㄱ': 574,
#  'ㄱㅏㅇㅣㅂ': 575,
#  'ㅈㅓㅅㅣㄴㅇㅛㅇㅈㅏㄷㅗ': 576,
#  'ㅅㅏㅇㅍㅜㅁㅇㅔ': 577,
#  'ㄱㅓㅂㅜㄹㅏㄱㅗ': 578,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 579,
#  'ㅈㅏㅂㅜㅎㅏㅂㄴㅣㄷㅏ': 580,
#  'ㅁㅕㅇㅈㅓㄹ': 581,
#  'ㅌㅗㅇㅎㅏㅂㅎㅐㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏㅇㅕㄴㅅㅗㄷㅡㄱㄷㅐㅂㅣ': 582,
#  'ㅊㅜㄱㅏㄹㅗ': 583,
#  'ㅈㅣㄴㅎㅐㅇㄱㅏㄴㅡㅇㅎㅏㅂㄴㅣㄷㅏ': 584,
#  'ㅇㅏㅇㅣㄷㅣㄱㅓㅁㅅㅐㄱㅎㅜ': 585,
#  'ㅂㅗㄴㅡㄴ': 586,
#  'ㄱㅡㅁ': 587,
#  'ㅊㅚㄱㅗㅎㅏㄴㄷㅗ': 588,
#  'ㅇㅓㄱㅇㅝㄴ': 589,
#  'ㅇㅏㄹㄱㅗ': 590,
#  'ㅂㅜㄹㅍㅕㄴㅎㅏㅅㅣㄴ': 591,
#  'ㄱㅠㄴㄷㅡㅇㅂㅏㅇㅅㅣㄱㅇㅡㄹㅗ': 592,
#  'ㅈㅜㄴㅡㄴ': 593,
#  'ㅁㅣㄱㅜㄱ': 594,
#  'ㅈㅣㅇㅝㄴㅎㅏㄱㅗ': 595,
#  'ㅊㅏㅈㅇㅏ': 596,
#  'ㄱㅣㄷㅐㅊㅜㄹㅇㅢ': 597,
#  'ㅊㅏㅈㅏㅇㅇㅗㄹㄹㅣㅁ': 598,
#  'ㄴㅏㅂㅂㅜ': 599,
#  'ㅍㅣㄹㅇㅛㅎㅏㄹㄸㅐ': 600,
#  'ㅊㅐ': 601,
#  'ㄷㅏ': 602,
#  'ㄱㅓㅂㅜㄹㅏㄴㅡㄴ': 603,
#  'ㅇㅑㅇㅎㅐㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 604,
#  'ㄱㅓㄴㅅㅜㄹㅡㄹ': 605,
#  'ㄱㅏㅁㅅㅗㅁㅣㅊ': 606,
#  'ㅊㅏ': 607,
#  'ㅈㅏㄱㅇㅡㄴ': 608,
#  'ㅈㅗㅅㅣㅁㅎㅏㅅㅣㄱㅗ': 609,
#  'ㄱㅡㄴㄹㅗㅈㅏㄷㅗ': 610,
#  'ㅅㅣㅈㅜㅇㅇㅡㄴㅎㅐㅇㄱㅝㄴㅇㅔㅅㅓ': 611,
#  'ㅈㅣㅇㅕㄴㄷㅚㄹㅅㅜ': 612,
#  'ㅎㅏㅅㅣㄱㅗ': 613,
#  'ㅈㅣㅈㅓㅁㅇㅡㄹㅗ': 614,
#  'ㅇㅕㄴㅂㅗㅇ': 615,
#  'ㄷㅚㅈㅣ': 616,
#  'ㅎㅏㄴㅎㅏㅇㅕ': 617,
#  'ㅇㅕㄴㄱㅡㅁㅇㅡㄹㅗ': 618,
#  'ㅎㅏㅅㅕㅅㅓ': 619,
#  'ㅇㅡㄴㅎㅐㅇㅇㅔㅅㅓㄴㅡㄴ': 620,
#  'ㄷㅚㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 621,
#  'ㅇㅏㄴㅣㅇㅗㄹㅏ': 622,
#  'ㅎㅐㄱㅅㅣㅁㅍㅗㅇㅣㄴㅌㅡ': 623,
#  'ㅈㅜㅅㅔㅇㅛ': 624,
#  'ㅎㅕㄴㄱㅡㅁㅅㅓㅂㅣㅅㅡ': 625,
#  'ㄴㅏㄹㅆㅣㄱㅏ': 626,
#  'ㅋㅏㅌㅗㄱ': 627,
#  'ㅈㅓㅎㅢㄱㅏ': 628,
#  'ㅇㅣㅈㅏㄱㅡㅁㅇㅐㄱ': 629,
#  'ㅁㅗㅅㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 630,
#  'ㄱㅏㄲㅡㅁㅆㅣㄱ': 631,
#  'ㅇㅏㄹㅐ': 632,
#  'ㄱㅏㅇㅣㅂㅎㅏㅈㅣ': 633,
#  'ㄸㅐㅁㅜㄴㅇㅔ': 634,
#  'ㄴㅐㅇㅛㅇㅇㅡㄹ': 635,
#  'ㅈㅣㅂㅏㅇㅅㅗㄷㅡㄱㅅㅔ': 636,
#  'ㅇㅝㄹㄴㅏㅂㅇㅣㅂㄱㅡㅁㅇㅐㄱㅇㅣ': 637,
#  'ㅂㅏㅇㅁㅜㄴ': 638,
#  'ㅁㅜㄴㅈㅏㅅㅜㅅㅣㄴㅂㅓㄴㅎㅗㄹㅗ': 639,
#  'ㅎㅐㅇㅂㅗㄱ': 640,
#  'ㅅㅣㄴㅇㅛㅇㅇㅔ': 641,
#  'ㅇㅗㅈㅓㄴ': 642,
#  'ㅇㅣㅈㅏㄹㅡㄹ': 643,
#  'ㄱㅏㄴㅡㅇㅎㅏㅅㅣㄹㅅㅜ': 644,
#  'ㅊㅗㅇㄱㅡㅂㅇㅕ': 645,
#  'ㅁㅜㄹㅛ': 646,
#  'ㄱㅡㄴㄹㅗㅅㅗㄷㅡㄱㅁㅏㄴ': 647,
#  'ㄱㅣㅃㅡㅁㅇㅣ': 648,
#  'ㅅㅣㄴㅊㅓㅇㅈㅏㄱㅏ': 649,
#  'ㄷㅚㄱㅗㅈㅏ': 650,
#  'ㄱㅡㄹㅣㄱㅗ': 651,
#  'ㅂㅏㅇㅅㅣㄱㅇㅡㄹ': 652,
#  'ㅅㅐㅇㄱㅏㄱㄷㅚㅇㅓ': 653,
#  'ㅇㅟㅎㅏㅇㅕ': 654,
#  'ㅎㅏㄴㄷㅗㄱㅡㅁㄹㅣㄹㅡㄹ': 655,
#  'ㅈㅣㄱㅇㅝㄴㅂㅓㄴㅎㅗ': 656,
#  'ㅇ': 657,
#  'ㅊㅜㅊㅓㄴㅈㅣㄱㅇㅝㄴ': 658,
#  'ㅅㅣㅈㅏㄱㅎㅏㄴㅡㄴ': 659,
#  'ㅅㅣㅇㅝㄴㅎㅏㄴ': 660,
#  'ㅅㅏㄹㅏㅇ': 661,
#  'ㄴㅏㅇㅢ': 662,
#  'ㄱㅖㅅㅗㄱ': 663,
#  'ㄷㅐㅎㅘㄴㅈㅏㄱㅡㅁㅊㅜㄱㅏㅈㅏㄱㅡㅁ': 664,
#  'ㅈㅔㅁㅗㄱㅇㅓㅄㅇㅡㅁ': 665,
#  'ㄱㅏㅇㅣㅂㅇㅣ': 666,
#  'ㅂㅜㄹㅍㅕㄴㅎㅏㅁㅇㅣ': 667,
#  'ㅎㅏㄴㅂㅜㄴ': 668,
#  'ㅊㅚㅅㅗㅎㅏㄴㅇㅢ': 669,
#  'ㄴㅕㄴㄷㅗ': 670,
#  'ㅂㅗㄷㅏㅂㅎㅏㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 671,
#  'ㅇㅜㄷㅐㄱㅡㅁㄹㅣ': 672,
#  'ㄱㅘㄴㅅㅣㅁㄱㅘ': 673,
#  'ㅇㅣㄹㅁㅏㄱㅏㅁ': 674,
#  'ㅈㅗㅅㅏㅅㅣ': 675,
#  'ㅁㅔㅅㅣㅈㅣㅇㅢ': 676,
#  'ㄱㅗㅇㅁㅜㅇㅝㄴㅇㅚㄱㅏㅁㅇㅓㅂㅊㅔㄷㅐㄱㅣㅇㅓㅂ': 677,
#  'ㄲㅗㅇㅗㄱ': 678,
#  'ㅈㅣㄱㅈㅏㅇㅇㅣㄴㅇㅣㅁㅕㄴㅂㅜㅊㅐㄱㅘㄷㅏㄹㅗㅇㅣㄴㅎㅐ': 679,
#  'ㅋㅏㅌㅗㄱㅈㅜㅅㅣㅁㅕㄴ': 680,
#  'ㄱㅓㅂㅜㄹㅡㄹ': 681,
#  'ㅅㅓㅇㅇㅝㄴㅇㅔ': 682,
#  'ㅎㅣㅁㅇㅣ': 683,
#  'ㅋㅏㄷㅡㄹㅗㄴㅎㅕㄴㄱㅡㅁㅅㅓㅂㅣㅅㅡ': 684,
#  'ㅅㅓㄹㅠ': 685,
#  'ㅈㅣㅈㅓㅁㅇㅔㅅㅓ': 686,
#  'ㅂㅗㄴㅐㅅㅣㄱㅗ': 687,
#  'ㄴㅏㅂㅇㅣㅂㅎㅏㄴㅡㄴ': 688,
#  'ㅈㅓㄹㄱㅏㅁ': 689,
#  'ㅈㅓㅇㅂㅗㄹㅡㄹ': 690,
#  'ㅊㅜㄱㅏㅈㅏㄱㅡㅁ': 691,
#  'ㄷㅏㄴ': 692,
#  'ㄱㅓㅁㅅㅏ': 693,
#  'ㄱㅓㅅㅇㅣ': 694,
#  'ㅇㅘㄴㅎㅘㄷㅚㅇㅓ': 695,
#  'ㅎㅕㄴ': 696,
#  'ㅅㅏㅇㅓㅂㅈㅏ': 697,
#  'ㅁㅗㅂㅏㅇㅣㄹ': 698,
#  'ㅇㅝㄹㅇㅣ': 699,
#  'ㅈㅚㅅㅗㅇㅎㅏㅂㄴㅣㄷㅏ': 700,
#  'ㅈㅡㅇㅅㅣ': 701,
#  'ㄴㅐㅇㅛㅇㅇㅡㄴ': 702,
#  'ㅈㅏㅇㅠㄹㅗㅇㅜㄴ': 703,
#  'ㄸㅏㄹㅡㄴ': 704,
#  'ㅅㅣㄷㅐㅇㅣㅂㄴㅣㄷㅏ': 705,
#  'ㄱㅓㅅㅇㅡㄹㅗ': 706,
#  'ㄱㅡㅁㅇㅛㅇㅣㄹ': 707,
#  'ㅁㅏㄴㅇㅝㄴㅇㅣㅅㅏㅇ': 708,
#  'ㄱㅐㅍㅕㄴㄷㅚㅇㅓ': 709,
#  'ㅈㅗㅇㅎㅏㅂㅅㅗㄷㅡㄱ': 710,
#  'ㅍㅣㄹㅇㅛ': 711,
#  'ㅈㅓㄹㅅㅔ': 712,
#  'ㄷㅐㅊㅜㄹㄱㅣㄱㅏㄴ': 713,
#  'ㄷㅐㅂㅣ': 714,
#  'ㅊㅚㅅㅏㅇㅇㅢ': 715,
#  'ㅁㅜㅅㅜㅅㅜㄹㅛ': 716,
#  'ㅅㅣㄴㅇㅛㅇㄷㅗㄹㅡㄹ': 717,
#  'ㅎㅏㄴㅏ': 718,
#  'ㄴㅏㅂㅇㅣㅂㅇㅣ': 719,
#  'ㅂㅔㅍㅜㄹㅇㅓ': 720,
#  'ㅇㅣㄴㅌㅓㄴㅔㅅ': 721,
#  'ㄴㅓㅁㅜㄴㅏ': 722,
#  'ㅇㅣㅇㅛㅇㅎㅏㅅㅣㄹㅅㅜ': 723,
#  'ㅈㅣㄱㅇㅝㄴ': 724,
#  'ㅇㅓㅄㅇㅓ': 725,
#  'ㅎㅏㅅㅣㄹ': 726,
#  'ㄱㅡㅁㄹㅣㄱㅏ': 727,
#  'ㄷㅏㅇㅡㅁㄱㅘ': 728,
#  'ㄷㅐㅎㅐㅅㅓㄴㅡㄴ': 729,
#  'ㄱㅏㅈㅗㄱㄱㅘ': 730,
#  'ㅇㅣㄴㅆㅏㅇㅣㅌㅡ': 731,
#  'ㄴㅏㅇㅡㄴ': 732,
#  'ㅂㅏㅇㅂㅓㅂ': 733,
#  'ㅈㅓㅁㅇㅣ': 734,
#  'ㄱㅏㅇㅣㅂㅎㅏㄱㅗ': 735,
#  'ㄱㅐㅇㅣㄴㅎㅕㅇ': 736,
#  'ㅁㅏㄹㅆㅡㅁㅇㅡㄹ': 737,
#  'ㅅㅏㅇㅛㅇ': 738,
#  'ㅅㅣㅇㄱㅡㄹㅓㅇㅜㄴ': 739,
#  'ㅈㅓㄴ': 740,
#  'ㅇㅏㄹㅅㅜ': 741,
#  'ㅇㅣㅂㄱㅡㅁ': 742,
#  'ㅎㅏㄱㅗ': 743,
#  'ㅎㅢㅁㅏㅇㅇㅡㄹ': 744,
#  'ㅂㅕㄴㅎㅏㅁㅇㅓㅄㄴㅡㄴ': 745,
#  'ㅇㅏㄴㄴㅐㄷㅡㄹㅣㄱㅗㅈㅏ': 746,
#  'ㄱㅣㅂㅗㄴㅈㅓㄱㅇㅣㄴ': 747,
#  'ㅎㅏㄴㅂㅜㄴㅇㅔㄱㅔ': 748,
#  'ㄷㅐㅎㅘㄴㅎㅏㄹ': 749,
#  'ㄴㅏㅈㅇㅏ': 750,
#  'ㅇㅡㄴㅎㅐㅇㅇㅢ': 751,
#  'ㅅㅣㅈㅏㄱㅎㅏㅅㅔㅇㅛ': 752,
#  'ㅇㅏㄴㄴㅐㅇㅏㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 753,
#  'ㅁㅜㄴㅈㅏㅇㅣㄴㅏ': 754,
#  'ㅈㅣㅈㅓㅁㅇㅔ': 755,
#  'ㅅㅓㅇㅎㅏㅁ': 756,
#  'ㄷㅐㅊㅜㄹㄱㅡㅁㄹㅣ': 757,
#  'ㄱㅡㅁㄹㅣㅂㅕㄴㄷㅗㅇ': 758,
#  'ㅎㅘㄴㅈㅓㄴ': 759,
#  'ㅎㅘㄱㅇㅣㄴㄱㅏㄴㅡㅇ': 760,
#  'ㄴㅏㅂㅇㅣㅂㄱㅡㅁㅇㅐㄱㅇㅔ': 761,
#  'ㄱㅏㅅㅏㅇㅈㅗㅎㅚㄹㅗ': 762,
#  'ㄷㅏㅈㅜㅇㅊㅐㅁㅜㅈㅏ': 763,
#  'ㅅㅔㅇㅐㄱㄱㅗㅇㅈㅔㄹㅡㄹ': 764,
#  'ㄴㅜㄹㄹㅓㅈㅜㅅㅣㅁㅕㄴ': 765,
#  'ㅂㅗㄷㅏ': 766,
#  'ㄱㅏㄴㅍㅕㄴㅎㅏㄱㅔ': 767,
#  'ㅊㅚㄱㅡㄴㅂㅜㄱㅕㄹㅈㅏ': 768,
#  'ㅇㅏㅂㄹㅠㄱㅏ': 769,
#  'ㄹㅣㅂㅡㄹㅡㄹ': 770,
#  'ㅅㅏㅎㅏㅇㅇㅣ': 771,
#  'ㄱㅡㅁㅇㅐㄱㅇㅔ': 772,
#  'ㄱㅏㅇㅈㅔㅅㅓㅇㅇㅣ': 773,
#  'ㅋㅓㅈㅣㅂㄴㅣㄷㅏ': 774,
#  'ㄷㅐㅎㅘㄴ': 775,
#  'ㅈㅜㅅㅔㅇㅛㄱㅝㄴㅇㅠㅈㅣㄱㅇㅝㄴ': 776,
#  'ㅈㅓㄴㄷㅏㄹㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 777,
#  'ㅅㅣㅈㅏㄱ': 778,
#  'ㄱㅜㄱ': 779,
#  'ㅇㅣㄹㅓㄴ': 780,
#  'ㅈㅔㄷㅗㄹㅡㄹ': 781,
#  'ㅇㅚㅇㅢ': 782,
#  'ㅂㅜㅌㅏㄱㄷㅡㄹㅕㅇㅛ': 783,
#  'ㄷㅡㄹㅣㅁㅕ': 784,
#  'ㅎㅗㅁㅍㅔㅇㅣㅈㅣ': 785,
#  'ㅅㅣㄴㅊㅓㅇ': 786,
#  'ㄷㅏㅁㄷㅏㅇㅈㅏ': 787,
#  'ㅇㅣㄹㅇㅣㄹㅇㅣ': 788,
#  'ㅈㅐㅂㅏㄹㅅㅗㅇ': 789,
#  'ㅇㅏㄶㅇㅡㅅㅣㄱㅓㄴㅏ': 790,
#  'ㅅㅐ': 791,
#  'ㅇㅕㄴㄱㅡㅁㅅㅗㄷㅡㄱㅅㅔ': 792,
#  'ㅂㅜㄴㄷㅡㄹㅊㅐㅁㅜㄱㅡㅁㅇㅐㄱㅇㅡㄴ': 793,
#  'ㅅㅔㄱㅡㅁㅎㅖㅌㅐㄱㅇㅡㄴ': 794,
#  'ㅇㅏㄹㄹㅣㅁ': 795,
#  'ㅁㅗㄱ': 796,
#  'ㅎㅐㅇㅂㅗㄱㅎㅏㄴㅎㅏㄹㅜ': 797,
#  'ㄴㅗㅎㅜㅅㅓㄹㄱㅖ': 798,
#  'ㅇㅜㄴㅇㅛㅇㅅㅜㅇㅣㄱㅇㅡㄴ': 799,
#  'ㅈㅣㅈㅓㅁㄱㅘ': 800,
#  'ㄷㅜㅂㅓㄴ': 801,
#  'ㅂㅏㅇㅁㅜㄴㅎㅐ': 802,
#  'ㄱㅖㅈㅘㄹㅗ': 803,
#  'ㅂㅏㅇㅂㅓㅂㅇㅡㄹ': 804,
#  'ㅍㅡㄹㄹㅔㅇㅣㅅㅡㅌㅗㅇㅓㅇㅔㅅㅓ': 805,
#  'ㅇㅜㅅㅜㅈㅣㄱㅇㅝㄴ': 806,
#  'ㅇㅜㅅㅇㅡㅁ': 807,
#  'ㅂㅜㅌㅏㄱㄷㅡㄹㅣㅁㅕ': 808,
#  'ㅇㅕㄴㄹㅏㄱㅈㅜㅅㅔㅇㅛ': 809,
#  'ㅅㅔㅈㅔㅎㅖㅌㅐㄱ': 810,
#  'ㄱㅏㅇㅣㅂㅇㅡㄹ': 811,
#  'ㅅㅏㅇㅛㅇㅈㅏ': 812,
#  'ㄴㅏㅂㅇㅣㅂㅇㅔ': 813,
#  'ㄷㅐㅊㅜㄹㅎㅏㄴㄷㅗㄹㅡㄹ': 814,
#  'ㅈㅐㅈㅣㄱ': 815,
#  'ㄴㅏㅂㅇㅣㅂㅎㅏㅅㅣㄴㅡㄴ': 816,
#  'ㅅㅣㅍㅇㅓㄷㅗ': 817,
#  'ㅅㅣㄴㅊㅓㅇㄱㅣㄱㅏㄴ': 818,
#  'ㄱㅏㄴㅡㅇㅎㅐㅈㅕㅆㅅㅡㅂㄴㅣㄷㅏ': 819,
#  'ㅅㅡㅁㅏㅌㅡㅍㅗㄴ': 820,
#  'ㄱㅡㅁㄴㅕㄴ': 821,
#  'ㅇㅜㄴㅇㅛㅇㅅㅏㅇㅍㅜㅁㅇㅡㄹ': 822,
#  'ㅅㅓㄹㅁㅜㄴㅈㅓㄴㅎㅘ': 823,
#  'ㅅㅏㅇㅅㅣㄱㄱㅘ': 824,
#  'ㅎㅚㅅㅣㄴㅎㅏㅇㅕ': 825,
#  'ㅅㅏㅇㅅㅡㅇㅅㅣㅋㅕㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 826,
#  'ㅂㅗㄴㅅㅏㅇㅍㅜㅁㅇㅡㄴ': 827,
#  'ㅅㅣㄴㅇㅛㅇㄷㅡㅇㄱㅡㅂㅇㅔ': 828,
#  'ㅅㅏㄹㅏㅁㅇㅣ': 829,
#  'ㄱㅐㅈㅓㅇ': 830,
#  'ㅈㅜㅅㅣㄱㅣㄹ': 831,
#  'ㅈㅔㄷㅗ': 832,
#  'ㅊㅐㅁㅜ': 833,
#  'ㅇㅣㅆㅅㅏㅇㅗㄴㅣ': 834,
#  'ㅁㅜㅂㅗㅈㅡㅇ': 835,
#  'ㅁㅗㅅㅎㅏㅇㅕㅆㄷㅓㄴ': 836,
#  'ㄱㅏㅅㅏㅇㅈㅗㅎㅚㄹㅡㄹ': 837,
#  'ㅇㅑㄱㅅㅗㄱㅎㅏㅂㄴㅣㄷㅏ': 838,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅎㅏㅇㅅㅏㅇ': 839,
#  'ㄷㅐㅅㅏㅇㄱㅡㅁㅇㅐㄱㄱㅘ': 840,
#  'ㅂㅐㅈㅓㅇ': 841,
#  'ㅂㅜㄷㅏㅁㅎㅏㅁㅕㄴ': 842,
#  'ㅅㅏ': 843,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㄱㅘㅇㅢ': 844,
#  'ㅈㅜㅅㅣㄱㅗ': 845,
#  'ㅈㅓㅂㅅㅜ': 846,
#  'ㅇㅜㄷㅐㅎㅐ': 847,
#  'ㅌㅡㄱㅂㅕㄹㅎㅏㄴ': 848,
#  'ㄷㅐㅎㅘㄴㅈㅏㄱㅡㅁㅍㅗㅎㅏㅁ': 849,
#  'ㄱㅖㅈㅓㄹ': 850,
#  'ㄱㅏㅇㅡㄹㅇㅣ': 851,
#  'ㅈㅣㄱㅈㅏㅇㅇㅣㄴㄱㅣㅈㅜㄴ': 852,
#  'ㄱㅡㄴㄹㅗㅈㅏㅌㅚㅈㅣㄱㄱㅡㅂㅇㅕㅂㅗㅈㅏㅇㅂㅓㅂㅅㅣㅎㅐㅇㄹㅕㅇ': 853,
#  'ㅂㅜㄹㅍㅕㄴㅎㅏㄴ': 854,
#  'ㅁㅏㅇㅡㅁㅇㅡㄹ': 855,
#  'ㅇㅣㅆㅇㅡㅁㅕ': 856,
#  'ㅇㅣㅇㅛㅇ': 857,
#  'ㅎㅘㄱㅇㅣㄴㅎㅏㅅㅣㄹ': 858,
#  'ㅎㅏㄴㄱㅕㄹㄱㅏㅌㅇㅡㄴ': 859,
#  'ㅅㅜㄹㅕㅇㅎㅏㅁㅕㄴ': 860,
#  'ㅅㅗㄴㅎㅐㄹㅡㄹ': 861,
#  'ㅁㅏㄹㄱㅗ': 862,
#  'ㅊㅜㄹㄱㅡㅁ': 863,
#  'ㄷㅐㅊㅜㄹㅎㅏㄴㄷㅗ': 864,
#  'ㄷㅗㅇㅘㄷㅡㄹㅕㅆㄷㅓㄴ': 865,
#  'ㅅㅣㄴㅊㅓㅇㅂㅏㅇㅂㅓㅂㅁㅜㄴㅈㅏㄹㅗ': 866,
#  'ㅅㅏㅇㅛㅇㅈㅜㅇㅇㅣㅅㅣㄴㅂㅜㄴ': 867,
#  'ㄱㅖㅈㅘㅂㅓㄴㅎㅗ': 868,
#  'ㅊㅟㅎㅐㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 869,
#  'ㅇㅣㅇㅛㅇㅈㅜㅇㅇㅣㄴㅂㅜㄴㄷㅡㄹㅊㅐㅁㅜㅌㅗㅇㅎㅏㅂㅇㅢ': 870,
#  'ㄹㅏㅇㅜㄴㅈㅣ': 871,
#  'ㄱㅏㄴㅡㅇㅎㅏㄹ': 872,
#  'ㄱㅘㅈㅏㅇㅇㅣㅂㄴㅣㄷㅏ': 873,
#  'ㅅㅏㅇㅎㅘㄴㅅㅜㅅㅜㄹㅛ': 874,
#  'ㅇㅕㅇㅎㅑㅇㅇㅣ': 875,
#  'ㄴㅐㄱㅏ': 876,
#  'ㄱㅏㅌㅇㅣ': 877,
#  'ㅅㅏㅇㅎㅘㄴㄱㅏㄴㅡㅇ': 878,
#  'ㅅㅏㅇ': 879,
#  'ㅅㅏㄹ': 880,
#  'ㄱㅏㅁㅅㅏㅎㅏㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 881,
#  'ㄱㅗㄱㅐㄱㄴㅣㅁㅇㅗㄴㅡㄹ': 882,
#  'ㅇㅏㄴㄴㅐㅈㅏㅇㅇㅡㄹ': 883,
#  'ㅎㅖㅌㅐㄱㅇ': 884,
#  'ㅅㅔㅇㅐㄱㄱㅗㅇㅈㅔㅇ': 885,
#  'ㅂㅜㄴㄷㅡㄹㄲㅔ': 886,
#  'ㄱㅖㅅㅣㅂㄴㅣㄲㅏ': 887,
#  'ㄱㅣㅈㅜㄴㄱㅡㅁㄹㅣㄱㅏㅅㅏㄴㄱㅡㅁㄹㅣ': 888,
#  'ㅇㅔㄱㅔ': 889,
#  'ㅈㅓㅇㅎㅏㄴ': 890,
#  'ㅇㅣㅆㅇㅓㅅㅓ': 891,
#  'ㅃㅏㄹㄹㅣ': 892,
#  'ㄱㅓㄴㄱㅏㅇㅎㅏㄴ': 893,
#  'ㄹㅏㄱㅗ': 894,
#  'ㅇㅣㄴㅐ': 895,
#  'ㄷㅐㅇㅢ': 896,
#  'ㄷㅡㅇㄱㅡㅂㅇㅡㄹㅗ': 897,
#  'ㄱㅐㅇㅝㄹㅇㅣㅅㅏㅇ': 898,
#  'ㄱㅓㅁㅅㅐㄱㅎㅏㅅㅣㅁㅕㄴ': 899,
#  'ㅂㅏㄹㅐㅇㅛ': 900,
#  'ㄱㅣㅃㅡㄴㅅㅣㄱㅏㄴ': 901,
#  'ㄱㅣㅍㅇㅡㄴ': 902,
#  'ㅇㅣㅈㅓㄴㅇㅢ': 903,
#  'ㄱㅕㄹㅈㅓㅇㅇㅣㄹ': 904,
#  'ㅇㅣㅈㅔ': 905,
#  'ㅊㅜㄱㅎㅏㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 906,
#  'ㅈㅣㅅㅜㄱㅏ': 907,
#  'ㅂㅜㄹㅇㅣㅂㄱㅡㅁㅇㅡㄹ': 908,
#  'ㅈㅓㅇㄱㅣㅇㅖㄱㅡㅁㄱㅘ': 909,
#  'ㅂㅜㅌㅏㄱㄷㅡㄹㅣㄱㅔㅆㅅㅡㅂㄴㅣㄷㅏ': 910,
#  'ㅅㅡㅌㅗㅇㅓ': 911,
#  'ㅎㅘㄴㅈㅓㄴㅎㅏㅅㅣㄹ': 912,
#  'ㅈㅓㅁㅇㅡㄹ': 913,
#  'ㄱㅏㅇㅣㅂㅎㅏㅅㅣㄴ': 914,
#  'ㅎㅏㅅㅣㄱㅣ': 915,
#  'ㄴㅏㅁㄱㅕㅈㅜㅅㅣㅁㅕㄴ': 916,
#  'ㄱㅡㅁㅈㅓㄴㅈㅓㄱ': 917,
#  'ㅅㅏㄹㅏㅇㅎㅏㄴㅡㄴ': 918,
#  'ㅂㅕㄴㄱㅕㅇㅎㅏㅅㅣㄹ': 919,
#  'ㅇㅖㄱㅡㅁ': 920,
#  'ㅅㅓㄴㅌㅐㄱㅎㅏㄱㅗ': 921,
#  'ㅍㅓㄴㄷㅡㅅㅏㅇㅍㅜㅁ': 922,
#  'ㅇㅗㄹㄹㅣㅁㅁㅜㄹㅛㅅㅜㅅㅣㄴㄱㅓㅂㅜ': 923,
#  'ㅇㅏㅇㅣㅍㅗㄴ': 924,
#  'ㅇㅛㅈㅡㅁ': 925,
#  'ㅍㅡㄹㄹㅔㅇㅣㅅㅡㅌㅗㅇㅓ': 926,
#  'ㄹㅣㅂㅡㄴㅡㄴ': 927,
#  'ㅇㅣㄹㅇㅣㄹ': 928,
#  'ㅅㅗㄱㅇㅔ': 929,
#  'ㅎㅗㄱㅅㅣㄹㅏㄷㅗ': 930,
#  'ㅇㅜㅅㅇㅡㅁㅇㅡㄹㅗ': 931,
#  'ㅂㅗㅁ': 932,
#  'ㅎㅘㄴㅇㅠㄹㅇㅡㄹ': 933,
#  'ㅂㅗㄴㅐㄱㅗ': 934,
#  'ㅂㅗㅁㅇㅣ': 935,
#  'ㅇㅗㄹㄹㅕㅇㅑ': 936,
#  'ㅅㅏㅇㅍㅜㅁㅇㅏㄴㄴㅐ': 937,
#  'ㅁㅏㄴㅈㅗㄱㅎㅏㅅㅕㅆㄱㅣㄹ': 938,
#  'ㄱㅗㄹㄷㅡㄴㄹㅏㅇㅣㅍㅡ': 939,
#  'ㄴㅏㅁㅏㄴㅇㅢ': 940,
#  'ㅊㅏㅁ': 941,
#  'ㅅㅣㄴㄱㅠㅅㅏㅇㅍㅜㅁ': 942,
#  'ㅇㅗㄹㅠㄴㅏ': 943,
#  'ㄱㅓㅅㅇㅡㄴ': 944,
#  'ㅈㅏㄱㅕㄱㄱㅣㅈㅜㄴㄱㅘ': 945,
#  'ㅅㅣㄴㅊㅓㅇㅅㅣ': 946,
#  'ㅅㅏㅇㅍㅜㅁㅇㅝㄴㄹㅣㄱㅡㅁㄱㅠㄴㄷㅡㅇ': 947,
#  'ㅅㅣㄴㅊㅓㅇㅂㅏㅇㅂㅓㅂㅅㅏㅇㄷㅏㅁ': 948,
#  'ㅇㅡㄴㅎㅐㅇㄱㅘ': 949,
#  'ㅅㅏㅇㄷㅏㅁㄱㅏㄴㅡㅇㅎㅏㅅㅣㅂㄴㅣㄷㅏ': 950,
#  'ㅅㅣㄴㅇㅛㅇㅈㅗㅎㅚㄴㅡㄴ': 951,
#  'ㅂㅗ': 952,
#  'ㄷㅗㅇㅇㅝㄴㅎㅐ': 953,
#  'ㅅㅜㅅㅣㄴ': 954,
#  'ㅎㅠㅇㅣㄹ': 955,
#  'ㅎㅏㄴㅎㅐ': 956,
#  'ㅈㅣㅅㅗㄱㅈㅓㄱㅇㅣㄴ': 957,
#  'ㅎㅢㅁㅏㅇㅎㅏㅅㅣㄹ': 958,
#  'ㄷㅐㅊㅜㄹㄱㅡㅁㅇㅐㄱㅇㅡㄴ': 959,
#  'ㅈㅗㄱㅓㄴ': 960,
#  'ㅈㅗㄱㅓㄴㅁㅏㄴ': 961,
#  'ㅎㅗㄹㅆㅣㅎㅏㄴㄷㅗ': 962,
#  'ㅈㅜㅇㅇㅣㅅㅣㄴ': 963,
#  'ㄷㅚㄴ': 964,
#  'ㅈㅏㄴㅕ': 965,
#  'ㅅㅗㅇㄱㅡㅁㅇㅣ': 966,
#  'ㅊㅜㅅㅓㄱ': 967,
#  'ㅇㅐㅂㅅㅡㅌㅗㅇㅓㅇㅔㅅㅓ': 968,
#  'ㅈㅓㄴㅅㅏㄴㅇㅢ': 969,
#  'ㅂㅜㄷㅏㅁㅅㅡㄹㅓㅇㅜㅅㅣㄴ': 970,
#  'ㅋㅏㅌㅗㄱㅇㅔ': 971,
#  'ㅁㅏㄶㅇㅏㄷㅗ': 972,
#  'ㅈㅔㄱㅗㅇ': 973,
#  'ㅈㅣㅈㅓㅁㅈㅏㅇ': 974,
#  'ㄷㅗㄴ': 975,
#  'ㄷㅐㅎㅘㄴㅅㅏㅇㅍㅜㅁ': 976,
#  'ㅅㅏㅇㄷㅏㅁㅇㅣㄹㅏㄴㅡㄴ': 977,
#  'ㅂㅜㄴㄷㅡㄹ': 978,
#  'ㅌㅚㅈㅣㄱㅇㅕㄴㄱㅡㅁㅇㅔ': 979,
#  'ㅂㅚㅂㄱㅗ': 980,
#  'ㅇㅝㄹㄷㅗ': 981,
#  'ㄷㅡㄹㅣㄱㅔ': 982,
#  'ㅅㅏㄻㅇㅡㄹ': 983,
#  'ㅊㅚㅅㅓㄴㅇㅢ': 984,
#  'ㅅㅏㅇㅎㅘㄴㅂㅐㄹㅣㅇㅓ': 985,
#  'ㅇㅓㅈㅔㅂㅗㄷㅏ': 986,
#  'ㅈㅣㄱㄱㅜㄴㄱㅘ': 987,
#  'ㅁㅣㄹㅣ': 988,
#  'ㅈㅓㅇㅂㅜㅇㅔㅅㅓ': 989,
#  'ㅅㅗㅈㅜㅇㅎㅏㄴㄱㅓㄹㅐ': 990,
#  'ㅎㅏㄹㅜㅂㅗㄴㅐㅅㅔㅇㅛ': 991,
#  'ㄱㅏㅁㅅㅗㅅㅣㅋㅕㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 992,
#  'ㅌㅗㅇㅎㅏㅂㅇㅡㄹ': 993,
#  'ㄴㅕㄴㅁㅣㅁㅏㄴㄷㅗ': 994,
#  'ㅇㅝㄴㄹㅣㄱㅡㅁㄱㅠㄴㄷㅡㅇㅂㅏㅇㅅㅣㄱㅇㅡㄹㅗ': 995,
#  'ㅊㅣㄴㄱㅜㄷㅡㅇㄹㅗㄱㅁㅏㄴ': 996,
#  'ㄴㅗㄹㅕㄱㅇㅡㄹ': 997,
#  'ㅊㅚㅈㅗㅇ': 998,
#  'ㄷㅏㅂㅂㅕㄴ': 999,
#  ...}

# %%
glove.word_vectors
# Out:
# array([[-0.19787655, -0.13440955,  0.13852456, ...,  0.08905442,
#         -0.14362293,  0.27114329],
#        [-0.22072931, -0.31352288,  0.10031367, ...,  0.00255756,
#         -0.20289128,  0.25142753],
#        [-0.17239438, -0.1748533 ,  0.09027506, ..., -0.02894472,
#         -0.12553198,  0.13983379],
#        ...,
#        [ 0.00169862, -0.002237  ,  0.00033272, ...,  0.00039494,
#          0.00142482, -0.00108642],
#        [-0.00049516,  0.00111817, -0.00157066, ..., -0.00090297,
#         -0.00087071, -0.00111987],
#        [-0.00117491,  0.00144927,  0.00257118, ..., -0.00188591,
#          0.00131372,  0.00049556]])

# %% [markdown]
# %%time
# for k in range(10,210,10):
#     glove = Glove(no_components=200, learning_rate=0.01, random_state=42)
#     glove.fit(x.tocoo(), epochs=k, no_threads=4, verbose=False)
#     dictionary = {vocab:idx for idx, vocab in enumerate(idx2vocab)}
#     glove.add_dictionary(dictionary)
#
#     with open("../KB_NLP/glove_txt/glove.200D.{}E.txt".format(k),'w') as f:
#         for word in glove.dictionary:
#             f.write(word)
#             f.write(" ")
#             for i in range(0, 200):
#                 f.write(str(glove.word_vectors[glove.dictionary[word]][i]))
#                 f.write(" ")
#             f.write("\n")
#
#     print("{}th embedding DONE".format(k))

# %%
# %%time
for k in range(10,210,10):
    glove = Glove(no_components=200, learning_rate=0.01, random_state=42)
    glove.fit(x.tocoo(), epochs=k, no_threads=4, verbose=False)
    dictionary = {vocab:idx for idx, vocab in enumerate(idx2vocab)}
    glove.add_dictionary(dictionary)
    
    key_list = []
    for key in glove.dictionary.keys():
        key_list.append(key)
    
    dicts = {}
    for word, vector in zip(glove.dictionary.keys(), glove.word_vectors):
        dicts[word] = vector
    #keys = key_list
    #values = glove.word_vectors
    #for i in key_list:
    #    for j in values:
    #        dicts[i] = j
    with open("../KB_NLP/glove_pkl/glove.200D.{}.pkl".format(k),'wb') as f:
        pickle.dump(dicts,f)
    
    print("{}th embedding DONE".format(k))
# Out:
# 10th embedding DONE
# 20th embedding DONE
# 30th embedding DONE
# 40th embedding DONE
# 50th embedding DONE
# 60th embedding DONE
# 70th embedding DONE
# 80th embedding DONE
# 90th embedding DONE
# 100th embedding DONE
# 110th embedding DONE
# 120th embedding DONE
# 130th embedding DONE
# 140th embedding DONE
# 150th embedding DONE
# 160th embedding DONE
# 170th embedding DONE
# 180th embedding DONE
# 190th embedding DONE
# 200th embedding DONE
# CPU times: user 3h 5min 52s, sys: 1.15 s, total: 3h 5min 53s
# Wall time: 1h 47min 31s
